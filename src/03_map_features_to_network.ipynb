# %%
import os

from database import data_utils

import contextily as cx
import geopandas
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
from shapely.ops import nearest_points

# %%
# # Get traces from all data that was collected during a validation day
# data = data_utils.combine_all_folder_data("../data/kcm_validation")
# traces = data_utils.calculate_trace_df(data, 'file', 'tripid', 'locationtime', 'lat', 'lon', ['orientation','scheduledeviation','tripdistance','locationtime'])
# # Calculate and remove speeds that are unreasonable
# traces['speed_m_s'] = traces['tripdistance_diff'] / traces['locationtime_diff']
# traces = traces.loc[traces['speed_m_s']>0]
# traces = traces.loc[traces['speed_m_s']<35]
# # Add geometry
# traces = geopandas.GeoDataFrame(traces, geometry=geopandas.points_from_xy(traces.lon, traces.lat), crs="EPSG:4326")
# traces

# Get traces from all data that was collected during a validation day
data = data_utils.combine_all_folder_data("../data/nwy_all", n_sample=10)
traces = data_utils.calculate_trace_df(data, 'file', 'datedvehiclejourney', 'locationtime', 'lat', 'lon', ['bearing','locationtime'], use_coord_dist=True)
# Calculate and remove speeds that are unreasonable
traces['speed_m_s'] = traces['dist_calc'] / traces['locationtime_diff']
traces = traces.loc[traces['speed_m_s']>0]
traces = traces.loc[traces['speed_m_s']<35]
# Add geometry
traces = geopandas.GeoDataFrame(traces, geometry=geopandas.points_from_xy(traces.lon, traces.lat), crs="EPSG:4326")
traces
# Out:
#                       datedvehiclejourney   dataframe          vehicle mode  \
# 609951    250-100025-152-34-20220318-1690  2022-03-18   152_x0020_2717  bus
# 203576      250-10139-152-1-20220318-2532  2022-03-18   152_x0020_2829  bus
# 610063   250-1140011-152-102-20220318-975  2022-03-18  152_x0020_17913  bus
# 610080   250-1150012-152-108-20220318-957  2022-03-18   152_x0020_2723  bus
# 610101  250-1160015-152-109-20220318-1867  2022-03-18   152_x0020_2713  bus
# ...                                   ...         ...              ...  ...
# 24711          VKT:ServiceJourney:2_2_128  2022-11-26           761944  bus
# 24712          VKT:ServiceJourney:2_2_128  2022-11-26           761944  bus
# 24713          VKT:ServiceJourney:2_2_128  2022-11-26           761944  bus
# 24714          VKT:ServiceJourney:2_2_128  2022-11-26           761944  bus
# 24715          VKT:ServiceJourney:2_2_128  2022-11-26           761944  bus
#
#                    line linename direction         operator datasource  \
# 609951  OST:Line:150010       10   Inbound              150        OST
# 203576  OST:Line:150001        1   Inbound              150        OST
# 610063  OST:Line:150114      114   Inbound              150        OST
# 610080  OST:Line:150115      115  Outbound              150        OST
# 610101  OST:Line:150116      116   Inbound              150        OST
# ...                 ...      ...       ...              ...        ...
# 24711        VKT:Line:2       02   Inbound  VKT:Operator:76        VOT
# 24712        VKT:Line:2       02   Inbound  VKT:Operator:76        VOT
# 24713        VKT:Line:2       02   Inbound  VKT:Operator:76        VOT
# 24714        VKT:Line:2       02   Inbound  VKT:Operator:76        VOT
# 24715        VKT:Line:2       02   Inbound  VKT:Operator:76        VOT
#
#                lat  ...     delay        nextstop  locationtime collectedtime  \
# 609951   59.215026  ...      PT0S   NSR:Quay:3115  1.647609e+09    1647609070
# 203576  59.2835537  ...    PT3M8S   NSR:Quay:4472  1.647622e+09    1647622105
# 610063  59.2709533  ...   PT3M41S   NSR:Quay:3417  1.647594e+09    1647594121
# 610080   59.214124  ...     PT41S   NSR:Quay:3347  1.647592e+09    1647591850
# 610101  59.2143918  ...  -PT5M46S   NSR:Quay:4024  1.647611e+09    1647610656
# ...            ...  ...       ...             ...           ...           ...
# 24711   59.4029902  ...   PT2M17S  NSR:Quay:32350  1.669449e+09    1669449473
# 24712   59.4023572  ...   PT1M42S  NSR:Quay:32350  1.669449e+09    1669449498
# 24713   59.4004995  ...   PT2M15S  NSR:Quay:30502  1.669450e+09    1669449528
# 24714    59.398729  ...   PT1M57S  NSR:Quay:30502  1.669450e+09    1669449553
# 24715   59.3984367  ...   PT1M57S  NSR:Quay:30502  1.669450e+09    1669449585
#
#                   file bearing_diff locationtime_diff     dist_calc  \
# 609951  2022_03_18.pkl        275.0             258.0    242.452578
# 203576  2022_03_18.pkl        295.0             275.0    172.521579
# 610063  2022_03_18.pkl        125.0            2064.0  12733.617981
# 610080  2022_03_18.pkl        146.0             338.0   1554.972602
# 610101  2022_03_18.pkl          0.0            4915.0     21.838679
# ...                ...          ...               ...           ...
# 24711   2022_11_25.pkl        -14.0              21.0    216.179716
# 24712   2022_11_25.pkl          7.0              31.0     92.093735
# 24713   2022_11_25.pkl        -11.0              30.0    296.330822
# 24714   2022_11_25.pkl        -18.0              21.0    207.005651
# 24715   2022_11_25.pkl        -10.0              31.0     32.824874
#
#         speed_m_s                   geometry
# 609951   0.939739  POINT (10.93771 59.21503)
# 203576   0.627351  POINT (11.10427 59.28355)
# 610063   6.169389  POINT (10.74697 59.27095)
# 610080   4.600511  POINT (10.79286 59.21412)
# 610101   0.004443  POINT (10.94083 59.21439)
# ...           ...                        ...
# 24711   10.294272  POINT (10.46894 59.40299)
# 24712    2.970766  POINT (10.46789 59.40236)
# 24713    9.877694  POINT (10.46413 59.40050)
# 24714    9.857412  POINT (10.46300 59.39873)
# 24715    1.058867  POINT (10.46292 59.39844)
#
# [574260 rows x 22 columns]

# %%
# Map every trace to a network segment
with open('../data/processed_networks/kcm_segments.pkl', 'rb') as f:
    kcm_segments = pickle.load(f)

# Convert to WA north projection
kcm_segments = kcm_segments.to_crs('EPSG:32148')
traces = traces.to_crs('EPSG:32148')

kcm_segments
# Out:
#                                           segment_id  \
# 0      47.1879807_-122.007378_47.1879807_-122.007454
# 1      47.1879807_-122.007454_47.1879921_-122.007538
# 2      47.1879921_-122.005493_47.1879807_-122.007378
# 3      47.1879921_-122.007538_47.1880188_-122.007607
# 4      47.1880188_-122.007607_47.1880722_-122.007774
# ...                                              ...
# 74289  47.8718987_-122.008453_47.8720436_-122.008316
# 74290  47.8720436_-122.008316_47.8721886_-122.008179
# 74291  47.8721886_-122.008179_47.8724899_-122.007881
# 74292  47.8722839_-122.007362_47.8708878_-122.003891
# 74293  47.8724899_-122.007881_47.8722839_-122.007362
#
#                                                 geometry
# 0      LINESTRING (411017.499 21579.193, 411011.740 2...
# 1      LINESTRING (411005.393 21580.646, 411011.740 2...
# 2      LINESTRING (411160.374 21578.283, 411017.499 2...
# 3      LINESTRING (411000.209 21583.694, 411005.393 2...
# 4      LINESTRING (410987.644 21589.823, 411000.209 2...
# ...                                                  ...
# 74289  LINESTRING (412097.090 97610.407, 412107.583 9...
# 74290  LINESTRING (412118.076 97642.322, 412107.583 9...
# 74291  LINESTRING (412140.877 97675.477, 412118.076 9...
# 74292  LINESTRING (412436.607 97492.824, 412179.347 9...
# 74293  LINESTRING (412179.347 97651.983, 412140.877 9...
#
# [74294 rows x 2 columns]

# %%
# Sample from the traces, match to the network
traces_n = traces.sample(100000)
# There are duplicates when distance to segments is tied; just take first
traces_n = geopandas.sjoin_nearest(traces_n, kcm_segments, distance_col="join_dist").drop_duplicates(['tripid','locationtime'])
traces_n
# Out:
#              tripid  vehicleid        lat         lon  orientation  \
# 192503  562535522.0     4375.0  47.603071 -122.331692        132.0
# 97442   572957572.0     8027.0  47.603358 -122.331954        312.0
# 268304  573742322.0     4304.0  47.602911 -122.331547        132.0
# 32931   559798202.0     8023.0  47.603199 -122.331808        312.0
# 210548  586178062.0     8256.0  47.603480 -122.332065        132.0
# ...             ...        ...        ...         ...          ...
# 175862  585672302.0     8234.0  47.630989 -122.285105        215.0
# 112638  561662382.0     3758.0  47.365137 -122.494625        214.0
# 2128    407754332.0     7422.0  47.580553 -122.163935        357.0
# 83897   581737812.0     7353.0  47.627686 -122.132370        270.0
# 255788  572963412.0     8156.0  47.686284 -122.257200        349.0
#
#         scheduledeviation  totaltripdistance  tripdistance  closeststop  \
# 192503              138.0       13840.025884  12496.487096        538.0
# 97442               207.0        6784.023108    750.402654        490.0
# 268304             -161.0        5418.601052   4054.897643        538.0
# 32931                93.0       19929.902867   1564.203869        490.0
# 210548               36.0       20384.844584    492.430606        531.0
# ...                   ...                ...           ...          ...
# 175862               21.0        5616.848373   1307.489353      12280.0
# 112638              255.0       22581.935649  18118.924975      47230.0
# 2128                468.0       27271.571923  18334.697815      65300.0
# 83897               286.0       28342.850514  11249.760705      68400.0
# 255788              115.0       18370.053530    255.860204      10653.0
#
#         nextstop  ...            file  orientation_diff  \
# 192503     538.0  ...  2022_10_17.pkl              -1.0
# 97442     1340.0  ...  2022_10_17.pkl              -1.0
# 268304     538.0  ...  2022_10_17.pkl             -71.0
# 32931      515.0  ...  2022_09_30.pkl               0.0
# 210548     548.0  ...  2022_09_21.pkl              -2.0
# ...          ...  ...             ...               ...
# 175862   12280.0  ...  2022_09_30.pkl               1.0
# 112638   47255.0  ...  2022_11_12.pkl             -27.0
# 2128     67014.0  ...  2022_11_05.pkl               4.0
# 83897    68400.0  ...  2022_09_30.pkl               1.0
# 255788   10657.0  ...  2022_10_21.pkl             168.0
#
#        scheduledeviation_diff  tripdistance_diff  locationtime_diff  \
# 192503                  -19.0          91.394421               20.0
# 97442                   -54.0         321.178257               41.0
# 268304                  -21.0         142.825034               41.0
# 32931                     0.0          51.744562               19.0
# 210548                    0.0         111.392390               40.0
# ...                       ...                ...                ...
# 175862                  -15.0         257.175947               34.0
# 112638                    0.0         552.658694               40.0
# 2128                    -24.0         311.250660               20.0
# 83897                    11.0          98.291426               27.0
# 255788                   14.0         225.453174               51.0
#
#         speed_m_s                      geometry  index_right  \
# 192503   4.569721  POINT (387338.515 68147.460)        42418
# 97442    7.833616  POINT (387319.484 68179.779)        42418
# 268304   3.483537  POINT (387349.100 68129.483)        42418
# 32931    2.723398  POINT (387330.075 68161.793)        42418
# 210548   2.784810  POINT (387311.413 68193.487)        42418
# ...           ...                           ...          ...
# 175862   7.563998  POINT (390899.553 71183.694)        47955
# 112638  13.816467  POINT (374518.439 41951.378)         6893
# 2128    15.562533  POINT (399907.568 65412.363)        37363
# 83897    3.640423  POINT (402370.213 70611.326)        47297
# 255788   4.420650  POINT (393110.140 77291.185)        60715
#
#                                            segment_id     join_dist
# 192503  47.6027641_-122.331413_47.6034851_-122.332069  5.995422e-03
# 97442   47.6027641_-122.331413_47.6034851_-122.332069  5.928232e-03
# 268304  47.6027641_-122.331413_47.6034851_-122.332069  5.940015e-03
# 32931   47.6027641_-122.331413_47.6034851_-122.332069  5.995213e-03
# 210548  47.6027641_-122.331413_47.6034851_-122.332069  5.826043e-03
# ...                                               ...           ...
# 175862   47.6308937_-122.28524_47.6310387_-122.285034  2.308814e-02
# 112638  47.3649139_-122.494957_47.3654251_-122.494194  8.787029e-04
# 2128    47.5805779_-122.164429_47.5805473_-122.163826  2.527617e-02
# 83897        47.6275673_-122.13237_47.6278_-122.13237  3.363178e-11
# 255788  47.6862831_-122.257195_47.6863022_-122.257294  1.117724e-02
#
# [100000 rows x 22 columns]

# %%
traces.columns
# Out:
# Index(['datedvehiclejourney', 'dataframe', 'vehicle', 'mode', 'line',
#        'linename', 'direction', 'operator', 'datasource', 'lat', 'lon',
#        'bearing', 'delay', 'nextstop', 'locationtime', 'collectedtime', 'file',
#        'bearing_diff', 'locationtime_diff', 'dist_calc', 'speed_m_s',
#        'geometry'],
#       dtype='object')

# %%
traces.groupby(['vehicle']).agg(['count','mean','nunique'])
# Out:
# /var/folders/6p/76scpql109v8rhf5gm61sr4c0000gn/T/ipykernel_13468/3791283621.py:1: FutureWarning: ['datedvehiclejourney', 'dataframe', 'mode', 'line', 'linename', 'direction', 'operator', 'datasource', 'lat', 'lon', 'delay', 'nextstop', 'file', 'geometry'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   traces.groupby(['vehicle']).agg(['count','mean','nunique'])
#         bearing                     locationtime                        \
#           count        mean nunique        count          mean nunique
# vehicle
# 1400        115  210.408696      81          115  1.653362e+09     115
# 1401          4  299.500000       4            4  1.653050e+09       4
# 1402         88  130.681818      77           88  1.653137e+09      88
# 1403         26  168.423077      23           26  1.652837e+09      26
# 1404         87  189.655172      66           87  1.653356e+09      87
# ...         ...         ...     ...          ...           ...     ...
# 9821        250  124.296000     154          250  1.653205e+09     250
# 9822         28  250.750000      25           28  1.660331e+09      28
# 9823         73  186.273973      63           73  1.654674e+09      73
# 9824        315  155.790476     193          315  1.654788e+09     315
# 99         1153  196.534258     258         1153  1.656681e+09    1153
#
#         collectedtime                        bearing_diff  ...          \
#                 count           mean nunique        count  ... nunique
# vehicle                                                    ...
# 1400              115            inf     115          115  ...      91
# 1401                4   4.132614e+38       4            4  ...       4
# 1402               88            inf      88           88  ...      67
# 1403               26  6.336961e+257      26           26  ...      24
# 1404               87            inf      87           87  ...      64
# ...               ...            ...     ...          ...  ...     ...
# 9821              250            inf     250          250  ...     118
# 9822               28  5.884312e+277      28           28  ...      25
# 9823               73            inf      73           73  ...      50
# 9824              315            inf     315          315  ...     130
# 99               1153            inf    1153         1153  ...     208
#
#         locationtime_diff                     dist_calc                       \
#                     count        mean nunique     count         mean nunique
# vehicle
# 1400                  115   35.660870      21       115   268.539568     115
# 1401                    4  474.500000       4         4  2167.484359       4
# 1402                   88   64.738636      19        88   440.224011      88
# 1403                   26  461.884615      15        26   724.666382      26
# 1404                   87  136.781609      23        87   551.407065      87
# ...                   ...         ...     ...       ...          ...     ...
# 9821                  250   34.004000      23       250   515.120039     250
# 9822                   28  162.607143      11        28   552.162201      28
# 9823                   73   41.794521      13        73   532.021729      73
# 9824                  315   36.660317      37       315   320.200476     315
# 99                   1153   31.554206      36      1153   166.661191    1153
#
#         speed_m_s
#             count       mean nunique
# vehicle
# 1400          115  10.168612     115
# 1401            4   6.795510       4
# 1402           88  14.939588      88
# 1403           26  12.126651      26
# 1404           87  11.665553      87
# ...           ...        ...     ...
# 9821          250  18.090251     250
# 9822           28  13.073913      28
# 9823           73  15.975170      73
# 9824          315  10.935929     315
# 99           1153   6.180188    1153
#
# [1146 rows x 21 columns]
